# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# %matplotlib inline
import seaborn as sns; sns.set()
sns.pairplot(iris, hue='species', size=1.5);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Extract the feature matrix and target array from the DataFrame

# %%
X_iris = iris.drop('species',axis=1)
print(X_iris.shape)
X_iris.head()
# Out:
# (150, 4)
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
y_iris = iris['species']
print(y_iris.shape)
y_iris.head()
# Out:
# (150,)
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# Name: species, dtype: object

# %% [markdown]
# # Supervised learning example: Simple Linear Regression
# * simple linear regression: the common case of fitting a line to (x, y) data.
# * use numpy's simple data for regression example

# %%
# simple linear regression example - using simple data
rng = np.random.RandomState(42)
x = 10 * rng.rand(50)
y = 2 * x - 1 + rng.randn(50)
plt.scatter(x,y)

# %%
# Instanitiate LinearRegression class and specify that we would like to fit the intercept using the fit_intercept hyperparameter
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(fit_intercept=True)
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# we need to massage the data x to make it a matrix of size [n_samples, n_features]
# reshaping of the one-dimensional array
# numpy.newaxis -> to increase the dimension of the existing array by one more dimension. 1D array becomes 2D array.
X = x[:, np.newaxis]
X.shape
# Out:
# (50, 1)

# %%
# Fit the model to data
model.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# in Scifit-Learn, by convention all model parameters taht were learned during the fit() process have trailing underscores
model.coef_
# Out:
# array([1.9776566])

# %%
# in Scifit-Learn, by convention all model parameters taht were learned during the fit() process have trailing underscores
model.intercept_
# Out:
# -0.9033107255311164

# %%
# predit labels for unknown data. our "new data" will be a grid of x values
xfit = np.linspace(-1,11)
print(xfit.shape)
xfit
# Out:
# (50,)
# array([-1.        , -0.75510204, -0.51020408, -0.26530612, -0.02040816,
#         0.2244898 ,  0.46938776,  0.71428571,  0.95918367,  1.20408163,
#         1.44897959,  1.69387755,  1.93877551,  2.18367347,  2.42857143,
#         2.67346939,  2.91836735,  3.16326531,  3.40816327,  3.65306122,
#         3.89795918,  4.14285714,  4.3877551 ,  4.63265306,  4.87755102,
#         5.12244898,  5.36734694,  5.6122449 ,  5.85714286,  6.10204082,
#         6.34693878,  6.59183673,  6.83673469,  7.08163265,  7.32653061,
#         7.57142857,  7.81632653,  8.06122449,  8.30612245,  8.55102041,
#         8.79591837,  9.04081633,  9.28571429,  9.53061224,  9.7755102 ,
#        10.02040816, 10.26530612, 10.51020408, 10.75510204, 11.        ])

# %%
# reshape: we need to coerce these x values into a [n_samples, n_features] features matrix, then can feed it to the model
Xfit = xfit[:, np.newaxis]
yfit = model.predict(Xfit)
print(Xfit.shape)
# Out:
# (50, 1)

# %%
# A simple linear regression fit to the data
plt.scatter(x,y)
plt.plot(xfit, yfit);

# %% [markdown]
# # Supervised learning example: Iris Classification
# * use Gaussian naive Bayes as baseline model
#     * fast, no hyperparamester to choose,
#     * good model to be used as baseline - before explore whether improvements can be found thru more sophisticated models

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, ytrain, ytest = train_test_split(X_iris, y_iris, random_state=1)

# %%
# 1. choose model class
# 2. instantiate model
# 3. fit model to data
# 4. predict on new datas

from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(Xtrain, ytrain)
y_model = model.predict(Xtest)

# %%
# finally, use the accuracy_score utility to see the fraction of predicted labels that match their true value
from sklearn.metrics import accuracy_score
accuracy_score(ytest, y_model)

#accuracy is high, even this very naive classification algorithm is effective for this particular database!
# Out:
# 0.9736842105263158

# %% [markdown]
# # Unsupervised learning example: Iris Dimensionality
# * reduce dimensioanlity of Iris data so as to more easily visualize it
#     * ask whether there is a suitable lower-dimensional representation that retains the essential features of the data.
#     * easier to plot data in 2-dimensions than in 4-dimensions or higher!
#     * PCA - fast linear dimensionality reduction technique
# * note: Iris data is 4-dimensional: there are 4 features recorded for each sample

# %%
# 1. choose the model class
# 2. instantiate the model with hyperparameter
# 3. fit to data. notice y is not specific
# 4. transform the data to 2 dimensions

from sklearn.decomposition import PCA
model = PCA(n_components=2)
model.fit(X_iris)
X_2D = model.transform(X_iris)

# %%
print(X_2D.shape)
X_2D
# Out:
# (150, 2)
# array([[-2.68412563,  0.31939725],
#        [-2.71414169, -0.17700123],
#        [-2.88899057, -0.14494943],
#        [-2.74534286, -0.31829898],
#        [-2.72871654,  0.32675451],
#        [-2.28085963,  0.74133045],
#        [-2.82053775, -0.08946138],
#        [-2.62614497,  0.16338496],
#        [-2.88638273, -0.57831175],
#        [-2.6727558 , -0.11377425],
#        [-2.50694709,  0.6450689 ],
#        [-2.61275523,  0.01472994],
#        [-2.78610927, -0.235112  ],
#        [-3.22380374, -0.51139459],
#        [-2.64475039,  1.17876464],
#        [-2.38603903,  1.33806233],
#        [-2.62352788,  0.81067951],
#        [-2.64829671,  0.31184914],
#        [-2.19982032,  0.87283904],
#        [-2.5879864 ,  0.51356031],
#        [-2.31025622,  0.39134594],
#        [-2.54370523,  0.43299606],
#        [-3.21593942,  0.13346807],
#        [-2.30273318,  0.09870885],
#        [-2.35575405, -0.03728186],
#        [-2.50666891, -0.14601688],
# ...

# %%
# plot the results: insert results into the original Iris Dataframe, and use seaborn lmplot to show results
iris['PCA1'] = X_2D[:, 0]
iris['PCA2'] = X_2D[:, 1]
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species      PCA1  \
# 0           5.1          3.5           1.4          0.2  setosa -2.684126
# 1           4.9          3.0           1.4          0.2  setosa -2.714142
# 2           4.7          3.2           1.3          0.2  setosa -2.888991
# 3           4.6          3.1           1.5          0.2  setosa -2.745343
# 4           5.0          3.6           1.4          0.2  setosa -2.728717
#
#        PCA2
# 0  0.319397
# 1 -0.177001
# 2 -0.144949
# 3 -0.318299
# 4  0.326755

# %%
# plot the results: insert results into the original Iris Dataframe, and use seaborn lmplot to show results
# in 2-dimensions, species are fairly well separated. 
sns.lmplot('PCA1','PCA2', hue='species', data=iris, fit_reg=False )

# %% [markdown]
# ## Unsupervised learning: Iris Clustering
# * attempts to find distinct groups of data without reference to any labels.
# * here use a powerful clustering method: Gaussian mixture model (GMM)
#     * attemps to model the data as a collection of Gaussian blobs

# %%
# 1. choose the model class
# 2. instantiate the model w/ hyperparameters
# 3. fit to data, notice y is not specified!
# 4. determine cluster labels

from sklearn.mixture import GaussianMixture
model = GaussianMixture(n_components=3, covariance_type='full',)
model.fit(X_iris)
y_gmm = model.predict(X_iris)
y_gmm
print(y_gmm.shape)
# Out:
# (150,)

# %%
# 4. determine cluster labels = add cluster label to iris dataframe and plot using sns
iris['cluster'] = y_gmm

# plot the clusters
sns.lmplot('PCA1','PCA2', data=iris, hue='species', col='cluster', fit_reg=False)

'''
sentosa is perfectly separated within cluster 0, while there is small mixing between versicolor and virginica. 
'''
# Out:
# '\nsentosa is perfectly separated within cluster 0, while there is small mixing between versicolor and virginica. \n'
